# %%
# %matplotlib inline
import pandas as pd

# %%
cast = pd.read_csv('D:/Top mentor/Pthon_Files/File7/File/cast/cast.csv')
cast.head()
# Out:
#                   title    year      name   type                character  \
# 0        Closet Monster  2015.0  Buffy #1  actor                  Buffy 4
# 1       Suuri illusioni  1985.0    Homo $  actor                   Guests
# 2   Battle of the Sexes  2017.0   $hutter  actor          Bobby Riggs Fan
# 3  Secret in Their Eyes  2015.0   $hutter  actor          2002 Dodger Fan
# 4            Steve Jobs  2015.0   $hutter  actor  1988 Opera House Patron
#
#       n
# 0   NaN
# 1  22.0
# 2  10.0
# 3   NaN
# 4   NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
print("Total Movies listed in title:",cast['title'].nunique())
# Out:
# Total Movies listed in title: 166670

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
print("Earliest films:", cast['title'].head(2))
# Out:
# Earliest films: 0     Closet Monster
# 1    Suuri illusioni
# Name: title, dtype: object

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
print("Total Number of hamlet titles:", cast[cast['title']=="Hamlet"].shape[0])
# Out:
# Total Number of hamlet titles: 218

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
print("Total Number of North by Northwest titles:",cast[cast['title']=="North by Northwest"].shape[0])
# Out:
# Total Number of North by Northwest titles: 81

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
print(cast[cast['title']=="Hamlet"].head(1).sort_values('year', ascending= False))
# Out:
#        title    year        name   type              character    n
# 1615  Hamlet  1996.0  Riz Abbasi  actor  Attendant to Claudius  1.0

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
print(cast[cast['title']=="Treasure Island"].sort_values('year', ascending= False))
# Out:
#                    title    year               name   type  \
# 880460   Treasure Island  1999.0       Rio Hackford  actor
# 1637661  Treasure Island  1999.0      Nick Offerman  actor
# 1975279  Treasure Island  1999.0        Dolph Scott  actor
# 210668   Treasure Island  1999.0     Jonah Blechman  actor
# 1375015  Treasure Island  1999.0        J.P. Manoux  actor
# ...                  ...     ...                ...    ...
# 909157   Treasure Island  1918.0       Edwin Harley  actor
# 840745   Treasure Island  1918.0          Joe Grant  actor
# 339256   Treasure Island  1918.0  Francis Carpenter  actor
# 1715014  Treasure Island  1918.0         Lloyd Perl  actor
# 1291387  Treasure Island  1918.0       Elmo Lincoln  actor
#
#                        character     n
# 880460                      Hans  23.0
# 1637661                   Samuel   2.0
# 1975279                   Parker  11.0
# 210668                  The Body   3.0
# 1375015           Officer Hughes  18.0
# ...

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
print("Movies made in 1950:",(cast['year']==1950).sum())
# Out:
# Movies made in 1950: 14653

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
print("Movies made in 1960:",(cast['year']==1960).sum())
# Out:
# Movies made in 1960: 11551

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
print("Movies made from 1950 through 1959:",cast[(cast['year']>=1950) & (cast['year']<=1959)]['title'].nunique())
# Out:
# Movies made from 1950 through 1959: 9827

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
print(cast[cast['title']=="Batman"].head(1).sort_values('year', ascending= False))
# Out:
#         title    year          name   type    character   n
# 95672  Batman  1943.0  Frank Austin  actor  Hotel Clerk NaN

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
print("Total Number of roles:",cast[cast['title']=="Inception"]['character'].nunique())
# Out:
# Total Number of roles: 42

# %%
print(cast[cast['title']=="Inception"].nunique())
# Out:
# title         1
# year          1
# name         52
# type          1
# character    42
# n            31
# dtype: int64

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
print("Total not null values:", cast[cast['title']=="Inception"]['n'].notnull().sum())
# Out:
# Total not null values: 31

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
print("Total null values:", cast[cast['title']=="Inception"]['n'].isnull().sum())
# Out:
# Total null values: 21

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
print(cast[(cast['title']=="North by Northwest") & (cast['n'].notna())].sort_values('n', ascending= True))
# Out:
#                       title    year               name   type  \
# 840374   North by Northwest  1959.0         Cary Grant  actor
# 1404704  North by Northwest  1959.0        James Mason  actor
# 343701   North by Northwest  1959.0     Leo G. Carroll  actor
# 1634552  North by Northwest  1959.0        Philip Ober  actor
# 1229083  North by Northwest  1959.0      Martin Landau  actor
# 1746383  North by Northwest  1959.0       Edward Platt  actor
# 642085   North by Northwest  1959.0  Robert Ellenstein  actor
# 447893   North by Northwest  1959.0    Philip Coolidge  actor
# 1454363  North by Northwest  1959.0      Patrick McVey  actor
# 198496   North by Northwest  1959.0       Edward Binns  actor
# 1334726  North by Northwest  1959.0          Ken Lynch  actor
#
#                            character     n
# 840374            Roger O. Thornhill   1.0
# 1404704              Phillip Vandamm   3.0
# 343701                 The Professor   5.0
# 1634552              Lester Townsend   7.0
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
print(cast[(cast['title']=="Sleuth")& (cast['year']==1972) & (cast['n'].notnull())].sort_values('n', ascending = True))
# Out:
#           title    year                name   type  \
# 1644328  Sleuth  1972.0    Laurence Olivier  actor
# 314691   Sleuth  1972.0       Michael Caine  actor
# 360365   Sleuth  1972.0      Alec Cawthorne  actor
# 1412647  Sleuth  1972.0  John (II) Matthews  actor
# 1396572  Sleuth  1972.0        Teddy Martin  actor
#
#                           character    n
# 1644328                 Andrew Wyke  1.0
# 314691                  Milo Tindle  2.0
# 360365            Inspector Doppler  3.0
# 1412647  Detective Sergeant Tarrant  4.0
# 1396572      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
print(cast[(cast['title']=="Sleuth")& (cast['year']==2007)].sort_values('n', ascending = True))
# Out:
#           title    year                 name   type          character    n
# 314692   Sleuth  2007.0        Michael Caine  actor             Andrew  1.0
# 1246855  Sleuth  2007.0             Jude Law  actor               Milo  2.0
# 1741124  Sleuth  2007.0        Harold Pinter  actor        Man on T.V.  3.0
# 250297   Sleuth  2007.0      Kenneth Branagh  actor  Other Man on T.V.  NaN
# 360366   Sleuth  2007.0  Alec (II) Cawthorne  actor  Inspector Doppler  NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
print("Total roles credited:", cast[(cast['title']=="Hamlet") & (cast['year']==1921)]['n'].nunique())
# Out:
# Total roles credited: 5

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
print("Total roles were credited:", cast[(cast['title']=="Hamlet") & (cast['year']==1996) & (cast['name']=="Kenneth Branagh")]['name'].nunique())
# Out:
# Total roles were credited: 1

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
print("Total roles have been listed:",cast[cast['title']=="Hamlet"].shape[0])
# Out:
# Total roles have been listed: 218

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
print("Total number of people played ophalia:", cast[cast['character']=="Ophelia"]['name'].nunique())
# Out:
# Total number of people played ophalia: 7

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
print("Total number of people played the dude:", cast[cast['character']=="The Dude"]['name'].nunique())
# Out:
# Total number of people played the dude: 16

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
print("Total number of people played The stranger:", cast[cast['character']=="The Stranger"]['name'].nunique())
# Out:
# Total number of people played The stranger: 173

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
print("Total number of roles played by Sidney Poitier:", cast[cast['name']=="Sidney Poitier"].shape[0])
# Out:
# Total number of roles played by Sidney Poitier: 43

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
print("Total number of roles played by Judi Dench:", cast[cast['name']=="Judi Dench"].shape[0])
# Out:
# Total number of roles played by Judi Dench: 0

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
print(cast[(cast['name']=="Cary Grant") & (cast['year']==1940) & (cast['n']==2)].sort_values('year', ascending = True))
# Out:
#                    title    year        name   type character    n
# 840371  My Favorite Wife  1940.0  Cary Grant  actor      Nick  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
print(cast[(cast['name']=="Cary Grant") & (cast['year']==1940) ].sort_values('year', ascending = True))
# Out:
#                           title    year        name   type  \
# 840353          His Girl Friday  1940.0  Cary Grant  actor
# 840371         My Favorite Wife  1940.0  Cary Grant  actor
# 840397  The Howards of Virginia  1940.0  Cary Grant  actor
# 840399   The Philadelphia Story  1940.0  Cary Grant  actor
#
#                  character    n
# 840353        Walter Burns  1.0
# 840371                Nick  2.0
# 840397         Matt Howard  1.0
# 840399  C. K. Dexter Haven  1.0

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
print("Total roles were available in 1950:", cast[cast['year']==1950].shape[0])
# Out:
# Total roles were available in 1950: 14653

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %%
print("Total roles of actreses:", cast[cast['type']=="actresses"].shape[0])
# Out:
# Total roles of actreses: 0

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
print(cast['year'].sort_values(ascending = True))
# Out:
# 464860     1894.0
# 555929     1894.0
# 1718214    1900.0
# 1718063    1900.0
# 600975     1905.0
#             ...
# 505460     2022.0
# 1120090    2023.0
# 28489      2023.0
# 1697058    2023.0
# 2159948       NaN
# Name: year, Length: 2159949, dtype: float64

# %%
print("Total leading roles:",cast[(cast['year']>=1894) & (cast['year']<=1980) & (cast['n']==1)].shape[0])
# Out:
# Total leading roles: 38187

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
print("Total non-leading roles:",cast[(cast['year']>=1980)  & (cast['n']!=1)].shape[0])
# Out:
# Total non-leading roles: 1379506

# %%
print("Total leading roles:",cast[(cast['year']>=1894) & (cast['year']<=1980) & (cast['n']!=1)].shape[0])
# Out:
# Total leading roles: 703017

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
print("Total leading roles:",cast[(cast['year']>=1894) & (cast['year']<=1980) & (cast['n'].isnull())].shape[0])
# Out:
# Total leading roles: 299849
